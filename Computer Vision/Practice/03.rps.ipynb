# %%
import urllib.request
import zipfile
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
# 데이터 가져오기
url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
urllib.request.urlretrieve(url, 'rps.zip')
local_zip = 'rps.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('tmp/')
zip_ref.close()

# 데이터 경로
TRAINING_DIR = "tmp/rps/"

# ImageDataGenerator
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1. / 255, 
    rotation_range=5,           # 이미지 회전 
    width_shift_range=0.05,     # 가로 방향으로 이동
    height_shift_range=0.05,    # 세로 방향으로 이동
    zoom_range=0.05,            #  이미지 확대
    horizontal_flip=True,       # 횡 방향으로 이미지 반전
    fill_mode= 'reflect',       # 이미지를 이동이나 굴절시켰을때 빈 픽셀 값에 대하여 값을 채우는 방식
    validation_split=0.2        # train/validation 분할 비율
)

train_geneator = datagen.flow_from_directory(TRAINING_DIR,
                                             batch_size=32,
                                             class_mode='categorical',
                                             subset='training')

valid_genenator = datagen.flow_from_directory(TRAINING_DIR,
                                             batch_size=32,
                                             class_mode='categorical',
                                              subset='validation')
# Out:
# Found 2016 images belonging to 3 classes.
# Found 504 images belonging to 3 classes.

# %%
# 이미지 시각화
images = train_geneator[0][0][:10]
labels = train_geneator[0][1][:10]

fig, axes = plt.subplots(2,5, figsize=(25,10))

for idx, ax in enumerate(axes.flat):
    ax.tick_params(bottom=False, labelbottom=False,
                   left=False, labelleft=False)
    ax.imshow(images[idx])

    if labels[idx][0] == 1:
        ax.set_title('paper')
    elif labels[idx][1] == 1:
        ax.set_title('rock')
    else:
        ax.set_title('scissors')

plt.show()

# %%
# 모델링

## InceptionV3
transfer = tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(256,256,3))
transfer.trainable=False

model = tf.keras.models.Sequential([
                                    transfer,
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(128, activation='relu'),
                                    tf.keras.layers.Dense(32, activation='relu'),
                                    tf.keras.layers.Dense(3, activation='softmax')
])

# %%
# 모델 요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 6, 6, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 73728)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 73728)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               9437312
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 31,244,323
# Trainable params: 9,441,539
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
# 최적화 함수, 손실 함수, 평가 지표
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

# %%
# 체크 포인트 설정
checkpoint_path = 'my_checkpoint.ckpt'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                save_weights_only=True,
                                                save_best_only=True,
                                                monitor='val_loss',
                                                verbose=1)

# %%
# 모델 학습
hist = model.fit(train_geneator,
           validation_data = (valid_genenator),
           epochs=20,
           callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 63/63 [==============================] - 75s 652ms/step - loss: 0.9276 - acc: 0.9191 - val_loss: 0.3822 - val_acc: 0.9167
#
# Epoch 00001: val_loss improved from inf to 0.38219, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 63/63 [==============================] - 40s 641ms/step - loss: 0.0095 - acc: 0.9970 - val_loss: 0.3909 - val_acc: 0.9107
#
# Epoch 00002: val_loss did not improve from 0.38219
# Epoch 3/20
# 63/63 [==============================] - 39s 628ms/step - loss: 0.1103 - acc: 0.9807 - val_loss: 1.6259 - val_acc: 0.7937
#
# Epoch 00003: val_loss did not improve from 0.38219
# Epoch 4/20
# 63/63 [==============================] - 39s 624ms/step - loss: 0.0374 - acc: 0.9936 - val_loss: 1.2026 - val_acc: 0.8591
#
# Epoch 00004: val_loss did not improve from 0.38219
# Epoch 5/20
# 63/63 [==============================] - 40s 640ms/step - loss: 0.0342 - acc: 0.9931 - val_loss: 0.2502 - val_acc: 0.9504
#
# Epoch 00005: val_loss improved from 0.38219 to 0.25020, saving model to my_checkpoint.ckpt
# Epoch 6/20
# 63/63 [==============================] - 39s 617ms/step - loss: 0.0106 - acc: 0.9975 - val_loss: 1.2781 - val_acc: 0.8611
#
# Epoch 00006: val_loss did not improve from 0.25020
# Epoch 7/20
# 63/63 [==============================] - 41s 650ms/step - loss: 0.0217 - acc: 0.9955 - val_loss: 0.8654 - val_acc: 0.9167
#
# Epoch 00007: val_loss did not improve from 0.25020
# Epoch 8/20
# 63/63 [==============================] - 40s 629ms/step - loss: 0.0408 - acc: 0.9960 - val_loss: 0.3294 - val_acc: 0.9425
#
# Epoch 00008: val_loss did not improve from 0.25020
# Epoch 9/20
# 63/63 [==============================] - 40s 636ms/step - loss: 0.0181 - acc: 0.9960 - val_loss: 0.5837 - val_acc: 0.9187
#
# Epoch 00009: val_loss did not improve from 0.25020
# Epoch 10/20
# 63/63 [==============================] - 39s 615ms/step - loss: 2.1598e-04 - acc: 1.0000 - val_loss: 0.1223 - val_acc: 0.9742
#
# Epoch 00010: val_loss improved from 0.25020 to 0.12225, saving model to my_checkpoint.ckpt
# Epoch 11/20
# 63/63 [==============================] - 40s 642ms/step - loss: 0.0199 - acc: 0.9960 - val_loss: 0.2752 - val_acc: 0.9683
#
# Epoch 00011: val_loss did not improve from 0.12225
# Epoch 12/20
# 63/63 [==============================] - 39s 622ms/step - loss: 0.0050 - acc: 0.9990 - val_loss: 0.5873 - val_acc: 0.9286
#
# Epoch 00012: val_loss did not improve from 0.12225
# Epoch 13/20
# 63/63 [==============================] - 40s 635ms/step - loss: 0.0831 - acc: 0.9901 - val_loss: 8.8540 - val_acc: 0.5635
#
# Epoch 00013: val_loss did not improve from 0.12225
# Epoch 14/20
# 63/63 [==============================] - 40s 635ms/step - loss: 0.0546 - acc: 0.9936 - val_loss: 0.5816 - val_acc: 0.9266
#
# Epoch 00014: val_loss did not improve from 0.12225
# Epoch 15/20
# 63/63 [==============================] - 40s 638ms/step - loss: 0.0152 - acc: 0.9975 - val_loss: 2.2920 - val_acc: 0.8294
#
# Epoch 00015: val_loss did not improve from 0.12225
# Epoch 16/20
# 63/63 [==============================] - 38s 608ms/step - loss: 0.0073 - acc: 0.9985 - val_loss: 0.3767 - val_acc: 0.9663
#
# Epoch 00016: val_loss did not improve from 0.12225
# Epoch 17/20
# 63/63 [==============================] - 40s 641ms/step - loss: 0.0467 - acc: 0.9926 - val_loss: 0.1222 - val_acc: 0.9821
#
# Epoch 00017: val_loss improved from 0.12225 to 0.12223, saving model to my_checkpoint.ckpt
# Epoch 18/20
# 63/63 [==============================] - 39s 624ms/step - loss: 0.0052 - acc: 0.9980 - val_loss: 3.3375 - val_acc: 0.7817
#
# Epoch 00018: val_loss did not improve from 0.12223
# Epoch 19/20
# 63/63 [==============================] - 39s 618ms/step - loss: 0.0011 - acc: 0.9995 - val_loss: 0.8532 - val_acc: 0.8988
#
# Epoch 00019: val_loss did not improve from 0.12223
# Epoch 20/20
# 63/63 [==============================] - 40s 635ms/step - loss: 0.0049 - acc: 0.9990 - val_loss: 1.9746 - val_acc: 0.8294
#
# Epoch 00020: val_loss did not improve from 0.12223

# %%
# accuracy, loss 그래프
fig, axes = plt.subplots(1,2, figsize=(10, 5))

## Accuracy
axes[0].plot(hist.history['loss'], label='train')
axes[0].plot(hist.history['val_loss'], label='valiation')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('LOSS')
axes[0].legend()

## Loss
axes[1].plot(hist.history['acc'], label='train')
axes[1].plot(hist.history['val_acc'], label='validation')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('ACCURACY')
axes[1].legend()

plt.show()

# %%
# 모델 가중치 적용
model.load_weights(checkpoint_path)

# %%
# 모델 저장
model.save('rps.h5')
